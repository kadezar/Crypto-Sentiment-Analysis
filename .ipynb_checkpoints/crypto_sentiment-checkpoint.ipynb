# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Kade\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key='053fb2e94f894590aedcf7b609817c90')

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='relevancy',
                                      )
btc_articles['articles'][0]
# Out:
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Arielle Pardes',
#  'title': 'Miami’s Bitcoin Conference Left a Trail of Harassment',
#  'description': 'For some women, inappropriate conduct from other conference-goers continued to haunt them online.',
#  'url': 'https://www.wired.com/story/bitcoin-2022-conference-harassment/',
#  'urlToImage': 'https://media.wired.com/photos/627a89e3e37e715cb7d760d2/191:100/w_1280,c_limit/Bitcoin_Miami_Biz_GettyImages-1239817123.jpg',
#  'publishedAt': '2022-05-10T16:59:46Z',
#  'content': 'Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]'}

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(
    q = 'ethereum',
    language = 'en',
    sort_by = 'relevancy'
)
eth_articles['articles'][0]
# Out:
# {'source': {'id': 'engadget', 'name': 'Engadget'},
#  'author': 'Jon Fingas',
#  'title': "Here's what NFTs look like on Instagram",
#  'description': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital wallet and posting for the world to see. If you like, the social …",
#  'url': 'https://www.engadget.com/instagram-nft-details-131020868.html',
#  'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-05/2546c160-d05e-11ec-b75e-e45eaa8c5b2b',
#  'publishedAt': '2022-05-10T13:10:20Z',
#  'content': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars]"}

# %%
# Create the Bitcoin sentiment scores DataFrame
def get_sentiment_score(article, based_on):
    sentiments = []

    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos,
                based_on : text
            })

        except AttributeError:
            pass

    df = pd.DataFrame(sentiments)
    return df

btc_sentiment_df = get_sentiment_score(btc_articles, 'content')
btc_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.0772     0.000    0.964     0.036
# 1    -0.0516     0.061    0.882     0.056
# 2    -0.3269     0.143    0.772     0.085
# 3     0.3818     0.052    0.833     0.114
# 4     0.3400     0.000    0.928     0.072
# 5     0.7506     0.000    0.807     0.193
# 6    -0.4404     0.241    0.557     0.202
# 7    -0.3612     0.123    0.877     0.000
# 8    -0.3818     0.077    0.923     0.000
# 9    -0.2732     0.063    0.937     0.000
# 10   -0.2732     0.063    0.937     0.000
# 11    0.1027     0.066    0.859     0.076
# 12   -0.3818     0.077    0.923     0.000
# 13   -0.5499     0.106    0.894     0.000
# 14    0.2263     0.060    0.855     0.085
# 15    0.1280     0.000    0.958     0.042
# 16   -0.8593     0.300    0.646     0.054
# 17    0.4051     0.059    0.809     0.132
# 18   -0.1779     0.054    0.946     0.000
# 19   -0.2023     0.064    0.894     0.042
#
#                                               content
# 0   Now, even though there are a number of women-f...
# 1   A Bitcoin mining site powered by otherwise los...
# 2   Warren Buffett has always been a bitcoin skept...
# 3   As a kid, I remember when my father tried to u...
# 4   Image source, Getty Images\r\nThe value of Bit...
# 5   If youve ever felt like introducing some Vegas...
# 6   Cryptocurrency mixers are sometimes used to he...
# 7   Posted \r\nFrom Bitcoin's dramatic drop to a n...
# 8   May 11 (Reuters) - Bitcoin fell 7.23% to $28,7...
# 9   May 4 (Reuters) - Bitcoin rose 5.7% to $39,862...
# 10  April 26 (Reuters) - Bitcoin dropped 5.1% to $...
# 11  BTC fell to its lowest level since last July, ...
# 12  May 9 (Reuters) - Bitcoin dropped 7.81% to $31...
# 13  At a Mexican restaurant in North London a few ...
# 14  May 10 (Reuters) - Bitcoin has scant experienc...
# 15  The Central African Republic has adopted bitco...
# 16  After two linked cryptocurrencies collapsed an...
# 17  Sam Bankman-Fried, founder of the digital asse...
# 18  To its evangelists, bitcoin is a frictionless,...
# 19  El Salvador which became the first country to ...

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiment_df = get_sentiment_score(eth_articles, 'content')
eth_sentiment_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.6486     0.000    0.865     0.135
# 1    -0.2263     0.075    0.879     0.046
# 2    -0.2732     0.055    0.945     0.000
# 3     0.1280     0.000    0.954     0.046
# 4     0.5346     0.000    0.858     0.142
# 5     0.2716     0.000    0.935     0.065
# 6    -0.2732     0.063    0.937     0.000
# 7     0.6908     0.000    0.822     0.178
# 8    -0.6908     0.178    0.822     0.000
# 9    -0.3818     0.085    0.847     0.069
# 10   -0.2732     0.063    0.937     0.000
# 11   -0.2732     0.063    0.937     0.000
# 12   -0.3818     0.077    0.923     0.000
# 13   -0.3818     0.077    0.923     0.000
# 14   -0.1027     0.036    0.964     0.000
# 15    0.0000     0.000    1.000     0.000
# 16    0.1027     0.066    0.859     0.076
# 17   -0.1531     0.045    0.955     0.000
# 18   -0.3182     0.067    0.933     0.000
# 19    0.3400     0.000    0.928     0.072
#
#                                               content
# 0   Meta has revealed more of how NFTs will work o...
# 1   A multi-billion dollar cryptocurrency company ...
# 2   When Bored Ape Yacht Club creators Yuga Labs a...
# 3   GameStop is going all-in on crypto. The video ...
# 4   April 26 (Reuters) - Ether has promised to do ...
# 5   Ethereum is preparing for an upgrade thats bee...
# 6   There's a new metaverse project from the creat...
# 7   Editorial IndependenceWe want to help you make...
# 8   40 days ago Bitcoin sold for $47,454. It's pri...
# 9   When Nvidia launched its Ampere Lite Hash Rate...
# 10  May 4 (Reuters) - Bitcoin rose 5.7% to $39,862...
# 11  April 26 (Reuters) - Bitcoin dropped 5.1% to $...
# 12  May 11 (Reuters) - Bitcoin fell 7.23% to $28,7...
# 13  May 9 (Reuters) - Bitcoin dropped 7.81% to $31...
# 14  If you ever wanted to buy an NFT based on Ethe...
# 15  9 with 8 posters participating\r\nNvidia began...
# 16  BTC fell to its lowest level since last July, ...
# 17  The cryptocurrency boom over the past few year...
# 18  ApeCoin, the native cryptocurrency of the APE ...
# 19  Image source, Getty Images\r\nThe value of Bit...

# %%
# Describe the Bitcoin Sentiment
btc_sentiment_df.describe()
# Out:
#         Compound  Negative    Neutral   Positive
# count  20.000000  20.00000  20.000000  20.000000
# mean   -0.093390   0.08045   0.860050   0.059450
# std     0.389782   0.07613   0.104336   0.062439
# min    -0.859300   0.00000   0.557000   0.000000
# 25%    -0.366350   0.05350   0.827000   0.000000
# 50%    -0.190100   0.06300   0.888000   0.048000
# 75%     0.152575   0.08425   0.930250   0.085000
# max     0.750600   0.30000   0.964000   0.202000

# %%
# Describe the Ethereum Sentiment
eth_sentiment_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.050650   0.047500   0.911150   0.041450
# std     0.380318   0.044936   0.050224   0.056143
# min    -0.690800   0.000000   0.822000   0.000000
# 25%    -0.284450   0.000000   0.863500   0.000000
# 50%    -0.189700   0.059000   0.930500   0.000000
# 75%     0.163900   0.069000   0.939000   0.069750
# max     0.690800   0.178000   1.000000   0.178000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: BTC - 0.061300
#
# Q: Which coin had the highest compound score?
#
# A: ETH - 0.865500
#
# Q. Which coin had the highest positive score?
#
# A: ETH - 0.269000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
stop_words = set(stopwords.words('english'))
# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in stop_words]
    
    # Remove the stop words
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_sentiment_df['tokens'] = btc_sentiment_df['content'].apply(tokenizer)
btc_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0772     0.000    0.964     0.036
# 1   -0.0516     0.061    0.882     0.056
# 2   -0.3269     0.143    0.772     0.085
# 3    0.3818     0.052    0.833     0.114
# 4    0.3400     0.000    0.928     0.072
#
#                                              content  \
# 0  Now, even though there are a number of women-f...
# 1  A Bitcoin mining site powered by otherwise los...
# 2  Warren Buffett has always been a bitcoin skept...
# 3  As a kid, I remember when my father tried to u...
# 4  Image source, Getty Images\r\nThe value of Bit...
#
#                                               tokens
# 0  [now, even, though, there, are, a, number, of,...
# 1  [a, bitcoin, mining, site, powered, by, otherw...
# 2  [warren, buffett, ha, always, been, a, bitcoin...
# 3  [a, a, kid, i, remember, when, my, father, tri...
# 4  [image, source, getty, imagesthe, value, of, b...

# %%
# Create a new tokens column for Ethereum
eth_sentiment_df['tokens'] = eth_sentiment_df['content'].apply(tokenizer)
eth_sentiment_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.6486     0.000    0.865     0.135
# 1   -0.2263     0.075    0.879     0.046
# 2   -0.2732     0.055    0.945     0.000
# 3    0.1280     0.000    0.954     0.046
# 4    0.5346     0.000    0.858     0.142
#
#                                              content  \
# 0  Meta has revealed more of how NFTs will work o...
# 1  A multi-billion dollar cryptocurrency company ...
# 2  When Bored Ape Yacht Club creators Yuga Labs a...
# 3  GameStop is going all-in on crypto. The video ...
# 4  April 26 (Reuters) - Ether has promised to do ...
#
#                                               tokens
# 0  [meta, ha, revealed, more, of, how, nfts, will...
# 1  [a, multibillion, dollar, cryptocurrency, comp...
# 2  [when, bored, ape, yacht, club, creator, yuga,...
# 3  [gamestop, is, going, allin, on, crypto, the, ...
# 4  [april, 26, reuters, ether, ha, promised, to, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
big_string_1 = btc_sentiment_df['content'].str.cat()
processed_1 = tokenizer(big_string_1)
bigrams_1 = Counter(ngrams(processed_1, n=2))

# %%
# Generate the Ethereum N-grams where N=2
big_string_2 = eth_sentiment_df['content'].str.cat()
processed_2 = tokenizer(big_string_2)
bigrams_2 = Counter(ngrams(processed_2, n=2))

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_10_btc = token_count(bigrams_1, 10)
top_10_btc
# Out:
# [(('the', 'world'), 6),
#  (('reuters', 'bitcoin'), 5),
#  (('cryptocurrency', 'is'), 5),
#  (('from', 'the'), 4),
#  (('from', 'it'), 4),
#  (('it', 'previous'), 4),
#  (('previous', 'closebitcoin'), 4),
#  (('closebitcoin', 'the'), 4),
#  (('world', 'biggest'), 4),
#  (('biggest', 'and'), 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_10_eth = token_count(bigrams_2, 10)
top_10_eth
# Out:
# [(('the', 'world'), 6),
#  (('reuters', 'bitcoin'), 4),
#  (('it', 'previous'), 4),
#  (('previous', 'closebitcoin'), 4),
#  (('closebitcoin', 'the'), 4),
#  (('world', 'biggest'), 4),
#  (('biggest', 'and'), 4),
#  (('and', 'bestknown'), 4),
#  (('bestknown', 'cryptocurrency'), 4),
#  (('cryptocurrency', 'is'), 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc_btc = WordCloud().generate(big_string_1)
plt.imshow(wc_btc)

# %%
# Generate the Ethereum word cloud
wc_eth = WordCloud().generate(big_string_2)
plt.imshow(wc_eth)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: jinja2 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: colorama in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# Requirement already satisfied: importlib-metadata in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kade\anaconda3\envs\mlenv\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-05-23 15:26:31.109764: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-05-23 15:26:31.109785: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_text = (big_string_1)

# %%
# Run the NER processor on all of the text
doc_1 = nlp(bitcoin_text)

# Add a title to the document
doc_1.user_data["NER Visualization - Bitcoin"] = "NER Visualization - Bitcoin"

# %%
# Render the visualization
displacy.render(doc_1, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Now, even though there are a number of women-focused crypto spaces,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odeniran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]A Bitcoin mining site powered by otherwise lost gas from an oil well near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . | Photo by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FRANCOIS PICARD/AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br> Of all the corporate climate hype fl… [+6544 chars]Warren
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  made it clear that his opposition to crypt… [+2297 chars]As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of snow. You can guess how well that … [+3390 chars]Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The value of Bitcoin continued to fall over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as it dropped below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27,630
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ), according to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidelity Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that it would allow investors to put part of the… [+3239 chars]Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>From
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's dramatic drop to a new way to pay for your luxury
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gucci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  handbag, we round up the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's big stories in cryptocurrencie

# %%
# List all Entities
for ent in doc_1.ents:
    print(ent.text)
# Out:
# Odeniran
# Linden
# Texas
# April 4th
# 2022
# FRANCOIS PICARD/AFP
# Getty Images
# Buffett
# the weekend
# Buffett
# nearly three feet
# Getty Images
# the weekend
# 34,000
# 27,630
# Coinbase
# Last week
# Fidelity Investments
# the US Treasury
# Bitcoin
# Gucci
# week
# Kristy Kilburn
# May 11
# Reuters
# 7.23%
# 28,758.29
# 22:05 GMT
# Wednesday
# 2,241.68
# Bitcoin
# 40.4%
# +361
# Reuters
# 5.7%
# 39,862.84
# Wednesday
# 2,102.94
# Bitcoin
# 20.9%
# year
# 26
# Reuters
# 5.1%
# 38,391.36
# Tuesday
# 2,229.82
# Bitcoin
# 16%
# year
# +339
# last July
# 33,000
# the week
# last week
# Fed
# 9
# Reuters
# 7.81%
# 31,333.41
# Monday
# 2,655.98
# Bitcoin
# 35%
# Mexican
# North London
# a few weeks ago
# 10
# Reuters
# +4315
# Central African Republic
# second
# El Salvador
# Wednesday
# Faustin Archange
# two
# Seth Green's
# Nike
# Bankman-Fried
# FTX
# chars]El Salvador
# first
# September
# $36 million
# over 50%
# Thursday

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_text = (big_string_2)

# %%
# Run the NER processor on all of the text
doc_2 = nlp(ethereum_text)

# Add a title to the document
doc_2.user_data["NER Visualization - Ethereum"] = "NER Visualization - Ethereum"

# %%
# Render the visualization
displacy.render(doc_2, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has revealed more of how NFTs will work on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based test, you can show what you've bought or created for free by connecting your
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  account to a compatible digital walle… [+1223 chars]A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the comp… [+3475 chars]When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bored Ape Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  creators
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otherside
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT collection would launch on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it was predicted by many to be the biggest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launch ever. Otherside is an upcoming Bore… [+6669 chars]GameStop is going all-in on crypto. The video game retailer launched its own self-custodial Ethereum digital wallet, it said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The wallet will be accessible through a Google Chrome extension an… [+1491 chars]April 26 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The transition would overhaul the infrastructure of the worlds
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -largest blockcha… [+2824 chars]There's a new metaverse project from the creators of
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the &quot;Bored Apes Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# &quot; NFTs.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  they held a &quot;virtual land&quot; sale, reports
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , raising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly a third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a billion dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .At ab… [+2023 chars]Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]40 days ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Bitcoin sold for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47,454
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-alig

# %%
# List all Entities
for ent in doc_2.ents:
    print(ent.text)
# Out:
# Meta
# Instagram
# US
# Instagram
# Ethereum
# Yuga Labs
# Bored Ape Yacht Club
# Yuga Labs
# Otherside
# April 30
# NFT
# Monday
# Reuters
# No.2
# second
# the "Bored Apes Yacht Club
# Last night
# Bloomberg
# nearly a third
# a billion dollars
# chars]40 days ago
# 47,454
# 34,007
# 28%.About a third
# this week
# Nvidia
# Ethereum
# Reuters
# 5.7%
# 39,862.84
# Wednesday
# 2,102.94
# Bitcoin
# 20.9%
# year
# 26
# Reuters
# 5.1%
# 38,391.36
# Tuesday
# 2,229.82
# Bitcoin
# 16%
# year
# +339
# Reuters
# 7.23%
# 28,758.29
# 22:05 GMT
# Wednesday
# 2,241.68
# Bitcoin
# 40.4%
# +361
# 9
# Reuters
# 7.81%
# 31,333.41
# Monday
# 2,655.98
# Bitcoin
# 35%
# NFT
# Ethereum
# Last week
# chars]9
# 8
# Nvidia
# LHR
# Lite Hash Rate
# last year
# last July
# 33,000
# the week
# last week
# Fed
# the past few years
# NFT
# $29 billion
# Ecosystem
# 16%
# Monday
# 14.60
# Getty Images
# the weekend
# 34,000
# 27,630
# Coinbase

# %% [markdown]
# ---
